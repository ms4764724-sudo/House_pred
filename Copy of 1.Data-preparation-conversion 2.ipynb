# %%
import pandas as pd
import numpy as np

# %%
# Creating a dataset
data = {
    'ID': [1, 2, 2, 3, 4, 5, 6, 7, 8, 9],
    'Name': ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', None, 'Hannah', 'Ivan'],
    'Age': [25, 30, 30, np.nan, 45, 29, -5, 40, 35, 50],
    'Salary': [50000, 54000, 54000, 60000, None, 58000, 62000, 59000, 60000, 70000]
}

df = pd.DataFrame(data)
print("Original Data:")
print(df)
# Out:
# Original Data:
#    ID     Name   Age   Salary
# 0   1    Alice  25.0  50000.0
# 1   2      Bob  30.0  54000.0
# 2   2      Bob  30.0  54000.0
# 3   3  Charlie   NaN  60000.0
# 4   4    David  45.0      NaN
# 5   5      Eve  29.0  58000.0
# 6   6    Frank  -5.0  62000.0
# 7   7     None  40.0  59000.0
# 8   8   Hannah  35.0  60000.0
# 9   9     Ivan  50.0  70000.0

# %%
df.shape
# Out:
# (10, 4)

# %%
df.head()
# Out:
#    ID     Name   Age   Salary
# 0   1    Alice  25.0  50000.0
# 1   2      Bob  30.0  54000.0
# 2   2      Bob  30.0  54000.0
# 3   3  Charlie   NaN  60000.0
# 4   4    David  45.0      NaN

# %%
df.tail(2)
# Out:
#    ID    Name   Age   Salary
# 8   8  Hannah  35.0  60000.0
# 9   9    Ivan  50.0  70000.0

# %%
df.describe()
# Out:
#               ID        Age        Salary
# count  10.000000   9.000000      9.000000
# mean    4.700000  31.000000  58555.555556
# std     2.750757  15.779734   5725.188012
# min     1.000000  -5.000000  50000.000000
# 25%     2.250000  29.000000  54000.000000
# 50%     4.500000  30.000000  59000.000000
# 75%     6.750000  40.000000  60000.000000
# max     9.000000  50.000000  70000.000000

# %%
df.dtypes
# Out:
# ID          int64
# Name       object
# Age       float64
# Salary    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      10 non-null     int64
#  1   Name    9 non-null      object
#  2   Age     9 non-null      float64
#  3   Salary  9 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 452.0+ bytes

# %%
df.sample()
# Out:
#    ID Name   Age   Salary
# 1   2  Bob  30.0  54000.0

# %%
# Handling Missing Values
df.isnull().sum()
# Out:
# ID        0
# Name      1
# Age       1
# Salary    1
# dtype: int64

# %%
# df.dropna(inplace=True)

# %%
df
# Out:
#    ID     Name   Age   Salary
# 0   1    Alice  25.0  50000.0
# 1   2      Bob  30.0  54000.0
# 2   2      Bob  30.0  54000.0
# 3   3  Charlie   NaN  60000.0
# 4   4    David  45.0      NaN
# 5   5      Eve  29.0  58000.0
# 6   6    Frank  -5.0  62000.0
# 7   7     None  40.0  59000.0
# 8   8   Hannah  35.0  60000.0
# 9   9     Ivan  50.0  70000.0

# %%
df['Age'].mean()
# Out:
# 31.0

# %%
# Fill missing values
df['Name'].fillna("Unknown", inplace=True)
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Salary'].fillna(df['Salary'].median(), inplace=True)

# %%
df
# Out:
#    ID     Name   Age   Salary
# 0   1    Alice  25.0  50000.0
# 1   2      Bob  30.0  54000.0
# 2   2      Bob  30.0  54000.0
# 3   3  Charlie  31.0  60000.0
# 4   4    David  45.0  59000.0
# 5   5      Eve  29.0  58000.0
# 6   6    Frank  -5.0  62000.0
# 7   7  Unknown  40.0  59000.0
# 8   8   Hannah  35.0  60000.0
# 9   9     Ivan  50.0  70000.0

# %%
# Checking duplicates
df[df.duplicated()]
# Out:
#    ID Name   Age   Salary
# 2   2  Bob  30.0  54000.0

# %%
# Removing duplicates
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#    ID     Name   Age   Salary
# 0   1    Alice  25.0  50000.0
# 1   2      Bob  30.0  54000.0
# 3   3  Charlie  31.0  60000.0
# 4   4    David  45.0  59000.0
# 5   5      Eve  29.0  58000.0
# 6   6    Frank  -5.0  62000.0
# 7   7  Unknown  40.0  59000.0
# 8   8   Hannah  35.0  60000.0
# 9   9     Ivan  50.0  70000.0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Age, Salary]
# Index: []

# %%
df['Age']
# Out:
# 0    25.0
# 1    30.0
# 3    31.0
# 4    45.0
# 5    29.0
# 6    -5.0
# 7    40.0
# 8    35.0
# 9    50.0
# Name: Age, dtype: float64

# %%
# Handling Noise / Outliers
df.loc[df['Age'] < 0, 'Age'] = df['Age'].median()

# %%
df
# Out:
#    ID     Name   Age   Salary
# 0   1    Alice  25.0  50000.0
# 1   2      Bob  30.0  54000.0
# 3   3  Charlie  31.0  60000.0
# 4   4    David  45.0  59000.0
# 5   5      Eve  29.0  58000.0
# 6   6    Frank  31.0  62000.0
# 7   7  Unknown  40.0  59000.0
# 8   8   Hannah  35.0  60000.0
# 9   9     Ivan  50.0  70000.0

# %%
df.dtypes
# Out:
# ID          int64
# Name       object
# Age         int32
# Salary    float64
# dtype: object

# %%
# Data Conversion
df['Age'] = df['Age'].astype(int)

# %%
df['Salary']
# Out:
# 0    50000.0
# 1    54000.0
# 3    60000.0
# 4    59000.0
# 5    58000.0
# 6    62000.0
# 7    59000.0
# 8    60000.0
# 9    70000.0
# Name: Salary, dtype: float64

# %%
# Normalization (Optional)
df['Salary_Normalized'] = (df['Salary'] - df['Salary'].min()) / (df['Salary'].max() - df['Salary'].min())

# %%
df
# Out:
#    ID     Name  Age   Salary  Salary_Normalized
# 0   1    Alice   25  50000.0               0.00
# 1   2      Bob   30  54000.0               0.20
# 3   3  Charlie   31  60000.0               0.50
# 4   4    David   45  59000.0               0.45
# 5   5      Eve   29  58000.0               0.40
# 6   6    Frank   31  62000.0               0.60
# 7   7  Unknown   40  59000.0               0.45
# 8   8   Hannah   35  60000.0               0.50
# 9   9     Ivan   50  70000.0               1.00

# %%
# Exporting Cleaned Data
df.to_csv("cleaned_data.csv", index=True)
